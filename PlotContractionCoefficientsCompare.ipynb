# %%
import glob, os
import numpy as np
import matplotlib.pyplot as plt
os.chdir('Results')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-2af83edc9531> in <module>
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
# ----> 4 os.chdir('Results')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Results'

# %% [markdown]
# #  Contraction coefficient changes

# %% [markdown]
# ## CIfar10 dataset

# %%
FilePath='ContractionCoeffiComp/'    
parts=3
i=0
coefficients=[0.1, 1]
plt.style.use('ggplot')

FlieList=['CIFAR10[512, 0.1]TrainConvergenceChanges.npy',
         'CIFAR10[512, 1]TrainConvergenceChanges.npy']

for i in range(len(FlieList)):
    print(FilePath+FlieList[i])
    TestLoss=np.load(FilePath+FlieList[i])
    TestLossEpoches=TestLoss
    if i<parts:
        plt.plot(TestLossEpoches, lw=1.5)
    else:
        plt.plot(TestLossEpoches,'--', lw=1.5)
    i+=1   


plt.xlabel('Epoches')
plt.ylabel('Loss')

plt.legend(tuple(coefficients))
plt.savefig(FilePath+'ContractionCoefficientsCompare_CIFAR10.png',dpi=600)
# Out:
# ContractionCoeffiComp/CIFAR10[512, 0.1]TrainConvergenceChanges.npy
# ContractionCoeffiComp/CIFAR10[512, 1]TrainConvergenceChanges.npy

# %%
FilePath='ContractionCoeffiComp/'    
parts=3
i=0
coefficients=[0.1,1]
plt.style.use('ggplot')

FlieList=[ 'CIFAR10[512, 0.1]TestConvergenceChanges.npy','CIFAR10[512, 1]TestConvergenceChanges.npy']

for i in range(len(FlieList)):
    print(FilePath+FlieList[i])
    TestLoss=np.load(FilePath+FlieList[i])
    TestLossEpoches=TestLoss
    if i<parts:
        plt.plot(TestLossEpoches, lw=1.5)
    else:
        plt.plot(TestLossEpoches,'--', lw=1.5)
    i+=1   


plt.xlabel('Epoches')
plt.ylabel('Loss')

plt.legend(tuple(coefficients))
plt.savefig(FilePath+'ContractionCoefficientsCompare_CIFAR10.png',dpi=600)
# Out:
# ContractionCoeffiComp/CIFAR10[512, 0.1]TestConvergenceChanges.npy
# ContractionCoeffiComp/CIFAR10[512, 1]TestConvergenceChanges.npy

# %%
FilePath='ContractCoeffiComp/'    
parts=3
i=0
coefficients=[0.1, 0.2, 0.4, 0.6,1]
plt.style.use('ggplot')

FlieList=[ 'CIFAR10[512, 0.1]TrainConvergenceChanges.npy', 'CIFAR10[512, 0.2]TrainConvergenceChanges.npy',
'CIFAR10[512, 0.4]TrainConvergenceChanges.npy', 'CIFAR10[512, 0.6]TrainConvergenceChanges.npy',
         'CIFAR10[512, 1]TrainConvergenceChanges.npy']

for i in range(len(FlieList)):
    print(FilePath+FlieList[i])
    TestLoss=np.load(FilePath+FlieList[i])
    TestLossEpoches=TestLoss
    if i<parts:
        plt.plot(TestLossEpoches, lw=1.5)
    else:
        plt.plot(TestLossEpoches,'--', lw=1.5)
    i+=1   


plt.xlabel('Epoches')
plt.ylabel('Loss')

plt.legend(tuple(coefficients))
plt.savefig(FilePath+'ContractionCoefficientsCompare_CIFAR10.png',dpi=600)
# Out:
# ContractCoeffiComp/CIFAR10[512, 0.1]TrainConvergenceChanges.npy
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-a77ad0233342> in <module>
#      11 for i in range(len(FlieList)):
#      12     print(FilePath+FlieList[i])
# ---> 13     TestLoss=np.load(FilePath+FlieList[i])
#      14     TestLossEpoches=TestLoss
#      15     if i<parts:
#
# /usr/local/lib/python3.5/dist-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     370     own_fid = False
#     371     if isinstance(file, basestring):
# --> 372         fid = open(file, "rb")
#     373         own_fid = True
#     374     elif is_pathlib_path(file):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ContractCoeffiComp/CIFAR10[512, 0.1]TrainConvergenceChanges.npy'

# %%
FilePath='ContractCoeffiComp/'    
parts=1
i=0
coefficients=[0.1, 0.2, 0.4, 0.6 ]
plt.style.use('ggplot')
FileList=['CIFAR10[512, 0.1]TestConvergenceChanges.npy','CIFAR10[512, 0.2]TestConvergenceChanges.npy',
          'CIFAR10[512, 0.4]TestConvergenceChanges.npy','CIFAR10[512, 0.6]TestConvergenceChanges.npy',
         'CIFAR10[512, 1]TestConvergenceChanges.npy']
for i in range(5):
    print(FilePath+FileList[i])
    TestLoss=np.load(FilePath+FileList[i])
    TestLossEpoches=TestLoss
    if i<parts:
        plt.plot(TestLossEpoches, lw=1.5)
    else:
        plt.plot(TestLossEpoches,'--', lw=1.5)
    i+=1   


plt.xlabel('Epoches')
plt.ylabel('Loss')

plt.legend(tuple(coefficients))
plt.savefig(FilePath+'ContractionCoefficientsCompare_CIFAR10.png',dpi=600)
# Out:
# ContractCoeffiComp/CIFAR10[512, 0.1]TestConvergenceChanges.npy
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-b9acba726b36> in <module>
#       9 for i in range(5):
#      10     print(FilePath+FileList[i])
# ---> 11     TestLoss=np.load(FilePath+FileList[i])
#      12     TestLossEpoches=TestLoss
#      13     if i<parts:
#
# /usr/local/lib/python3.5/dist-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     370     own_fid = False
#     371     if isinstance(file, basestring):
# --> 372         fid = open(file, "rb")
#     373         own_fid = True
#     374     elif is_pathlib_path(file):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ContractCoeffiComp/CIFAR10[512, 0.1]TestConvergenceChanges.npy'

# %% [markdown]
# # Batch Size changes

# %% [markdown]
# ## MNIST

# %%
parts=3
i=0
coefficients=[64,128,256,512, 1024]
plt.style.use('ggplot')
FilePath='BatchSizeComp/'    

filelist=['MNIST[64, 1]TrainConvergenceChanges.npy',
'MNIST[128, 1]TrainConvergenceChanges.npy',
'MNIST[256, 1]TrainConvergenceChanges.npy',
'MNIST[512, 1]TrainConvergenceChanges.npy',
'MNIST[1024, 1]TrainConvergenceChanges.npy'
]
    
for i in range(5):
    TestLoss=np.load(FilePath+filelist[i])
    TestLossEpoches=TestLoss
    if i<parts:
        plt.plot(TestLossEpoches[1:80], lw=1.5)
    else:
        plt.plot(TestLossEpoches[1:80],'--', lw=1.5)
    i+=1   


plt.xlabel('Epoches')
plt.ylabel('Loss')

plt.legend(tuple(coefficients))
plt.savefig(FilePath+'TrainBatchSizeCompare_MNIST.png',dpi=600)

# %%
parts=3
i=0
coefficients=[64,128,256,512, 1024]
plt.style.use('ggplot')
FilePath='tmp/'    
filelist=[ 'MNIST[64, 1]TrainConvergenceChanges.npy','MNIST[64, 1]TestConvergenceChanges.npy']
for i in range(2):
    TestLoss=np.load(FilePath+filelist[i])
    TestLossEpoches=TestLoss
    if i<parts:
        plt.plot(TestLossEpoches[1:80], lw=1.5)
    else:
        plt.plot(TestLossEpoches[1:80],'--', lw=1.5)
    i+=1   
plt.xlabel('Epoches')
plt.ylabel('Loss')

plt.legend(tuple(coefficients))
plt.savefig(FilePath+'TestBatchSizeCompare_MNIST.png',dpi=600)

# %%
parts=3
i=0
coefficients=[64,128,256,512,1024]
plt.style.use('ggplot')
FilePath='tmp/'
flielist=[ 'MNIST[64, 1]TestConvergenceChanges.npy','MNIST[128, 1]TestConvergenceChanges.npy',
          'MNIST[256, 1]TestConvergenceChanges.npy','MNIST[512, 1]TestConvergenceChanges.npy']
for i in range(4):
    
    if i<parts:
        plt.plot(TestLossEpoches[i][1:80], lw=1.5)
    else:
        plt.plot(TestLossEpoches[i][1:80],'--', lw=1.5)
    i+=1   


plt.xlabel('Epoches')
plt.ylabel('Loss')

plt.legend(tuple(coefficients))
plt.savefig(FilePath+'TestBatchSizeCompare_MNIST.png',dpi=600)

# %%
parts=3
i=0
coefficients=[64,128,256,512,1024]
plt.style.use('ggplot')
FilePath='tmp/'
flielist=[ 'MNIST[64, 1]TestConvergenceChanges.npy','MNIST[128, 1]TestConvergenceChanges.npy',
          'MNIST[256, 1]TestConvergenceChanges.npy','MNIST[512, 1]TestConvergenceChanges.npy']
TestLoss1=np.zeros((4,80))
for i in range(4):
    TestLoss1[i,:]=np.load(FilePath+flielist[i])
    
 
TestLossEpoches=TestLoss+TestLoss1

    
for i in range(4):
    
    if i<parts:
        plt.plot(TestLossEpoches[i][1:80], lw=1.5)
    else:
        plt.plot(TestLossEpoches[i][1:80],'--', lw=1.5)
    i+=1   


plt.xlabel('Epoches')
plt.ylabel('Loss')

plt.legend(tuple(coefficients))
plt.savefig(FilePath+'TestBatchSizeCompare_MNIST.png',dpi=600)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-24-77d20e30673f> in <module>
#       8 TestLoss1=np.zeros((4,80))
#       9 for i in range(4):
# ---> 10     TestLoss1[i,:]=np.load(FilePath+flielist[i])
#      11
#      12
#
# /usr/local/lib/python3.5/dist-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     370     own_fid = False
#     371     if isinstance(file, basestring):
# --> 372         fid = open(file, "rb")
#     373         own_fid = True
#     374     elif is_pathlib_path(file):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'tmp/MNIST[64, 1]TestConvergenceChanges.npy'

# %%
(TestLoss+TestLoss1).shape
# Out:
# (4, 80)

# %% [markdown]
# ## CIFAR10

# %%
parts=3
i=0
coefficients=[64,128,256,512, 1024]
plt.style.use('ggplot')
FilePath='BatchSizeComp/'    

filelist=['CIFAR10[64, 1]TrainConvergenceChanges.npy','CIFAR10[128, 1]TrainConvergenceChanges.npy','CIFAR10[256, 1]TrainConvergenceChanges.npy',
         'CIFAR10[512, 1]TrainConvergenceChanges.npy', 'CIFAR10[1024, 1]TrainConvergenceChanges.npy']
    
for i in range(5):
    TestLoss=np.load(FilePath+filelist[i])
    TestLossEpoches=TestLoss
    if i<parts:
        plt.plot(TestLossEpoches[1:80], lw=1.5)
    else:
        plt.plot(TestLossEpoches[1:80],'--', lw=1.5)
    i+=1   


plt.xlabel('Epoches')
plt.ylabel('Loss')

plt.legend(tuple(coefficients))
plt.savefig(FilePath+'TrainBatchSizeCompare_CIFAR10.png',dpi=600)

# %%
parts=3
i=0
coefficients=[64,128,256,512,1024]
plt.style.use('ggplot')

filelist=['CIFAR10[64, 1]TestConvergenceChanges.npy','CIFAR10[128, 1]TestConvergenceChanges.npy',
          'CIFAR10[256, 1]TestConvergenceChanges.npy', 'CIFAR10[512, 1]TestConvergenceChanges.npy',
                  'CIFAR10[1024, 1]TestConvergenceChanges.npy']

for i in range(5):
    TestLoss=np.load(FilePath+filelist[i])
    TestLossEpoches=TestLoss
    if i<parts:
        plt.plot(TestLossEpoches[1:80], lw=1.5)
    else:
        plt.plot(TestLossEpoches[1:80],'--', lw=1.5)
    i+=1   


plt.xlabel('Epoches')
plt.ylabel('Loss')

plt.legend(tuple(coefficients))
plt.savefig(FilePath+'TestBatchSizeCompare_CIFAR10.png',dpi=600)
